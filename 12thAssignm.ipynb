# %% [markdown]
# <a href="https://colab.research.google.com/github/pafernannapi18/GithubIntro/blob/main/12thAssignm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Problem 1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/content/drive/MyDrive/Train dataset/train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %% [markdown]
# Problem 2
#
# The dataset of housing information in the Ames City, Iowa is used for tax assessment purposes but lends itself directly to the prediction of home selling prices. The type of in of information contained in the data is similar to what a typical home buyer would want to know before making a purchase.

# %%
## Problem 3
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# Problem 3-a
#
# In this problem we have in all 81 variables.
# The float64 are 3.
# The in64 are 35.
# The summe of these two 38, they are numerical data.
# The last are Object data, and they are 43 variables.

# %%
## Problem 3-b
# Row location
df.iloc[:,80]
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %% [markdown]
# Problem 3-b
#
# The Target variable is in the Saleprice column.

# %%
# # Problem 3-c
# Mean, Standard deviation, and quartiles  
r = df.describe()
r
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
## Problem 4-a
Total = df.count()
Total
Missing_ratio = df.isna().mean()*100
Missing_ratio
Final = pd.concat([Total, Missing_ratio], axis=1)


Finals = Final.rename({'0':'Total', '1':'Missing_ratio'}, axis=1)
print(Finals)
# Out:
#                   0          1
# Id             1460   0.000000
# MSSubClass     1460   0.000000
# MSZoning       1460   0.000000
# LotFrontage    1201  17.739726
# LotArea        1460   0.000000
# ...             ...        ...
# MoSold         1460   0.000000
# YrSold         1460   0.000000
# SaleType       1460   0.000000
# SaleCondition  1460   0.000000
# SalePrice      1460   0.000000
#
# [81 rows x 2 columns]

# %%
## Problem 4-b
percentage= 0.3425
min_count = int(((100-percentage)/100)*df.shape[0]+1)
mod_df = df.dropna(axis = 1, thresh= min_count)
print(mod_df)
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType SaleCondition SalePrice
# 0        1          60       RL  ...        WD        Normal    208500
# 1        2          20       RL  ...        WD        Normal    181500
# 2        3          60       RL  ...        WD        Normal    223500
# 3        4          70       RL  ...        WD       Abnorml    140000
# 4        5          60       RL  ...        WD        Normal    250000
# ...    ...         ...      ...  ...       ...           ...       ...
# 1455  1456          60       RL  ...        WD        Normal    175000
# 1456  1457          20       RL  ...        WD        Normal    210000
# 1457  1458          70       RL  ...        WD        Normal    266500
# 1458  1459          20       RL  ...        WD        Normal    142125
# 1459  1460          20       RL  ...        WD        Normal    147500
#
# [1460 rows x 63 columns]

# %%
## Problem 4-c
perc = 7.9365
min_count = int(((100-percentage)/100)*mod_df.shape[0]+1)
mod_df2 = mod_df.dropna(axis= 0, thresh=min_count)
print(mod_df2)
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, ExterQual, ExterCond, Foundation, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, GarageCars, GarageArea, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %% [markdown]
# Problem 5
#
# Skewness
#
# Skewness is the degree of departure from symmetry of a distribution. A positively skewed distribution has a "tail" which is pulled in the positive direction. A negatively skewed distribution has a "tail" which is pulled in the negative direction.
#
# Kurtosis
#
# Kurtosis is the degree of peakedness of a distribution. A normal distribution is a mesokurtic distribution. A pure leptokurtic distribution has a higher peak than the normal distribution and has heavier tails. A pure platykurtic distribution has a lower peak than a normal distribution and lighter tails.

# %%
## Problem 6

import matplotlib.pyplot as plt
import matplotlib_inline 
import seaborn as sns

# %%
## Problem 6-a1
sns.displot(data=df, x="SalePrice", kde=True)

# %%
## Problem 6-a2
sns.histplot(data=df, x="SalePrice")

# %%
## Problem 6-a3
print(df['SalePrice'].astype(float).skew())
print(df['SalePrice'].astype(float).kurt())
# Out:
# 1.8828757597682129
# 6.536281860064529

# %%
## Problem 6-b

plt.figure(figsize=(5,7))
plt.hist(np.log1p(df.SalePrice), bins=100)
plt.xlabel("SalePrice")
plt.title("Histogram of SalePrice")
plt.show()

# %%
print(np.log1p(df.SalePrice).astype(float).skew())
print(np.log1p(df.SalePrice).astype(float).kurt())
# Out:
# 0.12134661989685333
# 0.809519155707878

# %% [markdown]
# # Problem 6-c
#
# The change that we can notice here is that before transformation the distribution of objective variables are almost concentrated in one side and the kurtosis and skewness has the highest values than after logarithmic transformation, and also the destributions of the objective variables were normal after log transformation.

# %%
## Problem 7-a

corr = df.corr()
corr
fig, ax = plt.subplots(figsize = (30,20))
sns.heatmap(corr, annot = True, ax = ax, cmap = 'coolwarm')
plt.title('Heat Map')
# Out:
# Text(0.5, 1.0, 'Heat Map')

# %% [markdown]
# # Problem 7-a1
#
# From the bipmap we can see that among our independent variables, the high correlation (0.882475) between two variables is: Garage.Cars and Garage.Area.
#
#  If we observe closely the heatmap it stands out the strong correlation relationship of value between GarageCars and GarageArea. These correlations are so strong that it can indicate a situation of multicollinearity. If we think about these variables, we can conclude that they give almost the same information so multicollinearity really occurs.

# %%
## Problem 7-b
def corrFilter(x: pd.DataFrame, bound: float):
  xCorr = x.corr()
  xFiltered = xCorr[((xCorr >= bound) | (xCorr <= -bound)) & (xCorr != 1.000)]
  xFlattened  = xFiltered.unstack().sort_values().drop_duplicates()
  return xFlattened

corrFilter(df, .641)
# Out:
# GarageYrBlt   YearRemodAdd    0.642277
# BsmtFinSF1    BsmtFullBath    0.649212
# TotRmsAbvGrd  BedroomAbvGr    0.676620
# 2ndFlrSF      GrLivArea       0.687501
# GrLivArea     SalePrice       0.708624
# SalePrice     OverallQual     0.790982
# 1stFlrSF      TotalBsmtSF     0.819530
# GrLivArea     TotRmsAbvGrd    0.825489
# GarageYrBlt   YearBuilt       0.825667
# GarageCars    GarageArea      0.882475
# Id            Id                   NaN
# dtype: float64

# %%
## Problem 7-b
dfCorr = df.corr()
filteredDf = dfCorr[((dfCorr >= 0.641) | (dfCorr <= -0.641)) & (dfCorr !=1.000)]
plt.figure(figsize=(30, 10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.heatmap(filteredDf, annot=True, cmap="Reds", annot_kws={"size":15})
plt.show()

# %% [markdown]
# # Problem 7-c
#
# The 10 selected values represent the features highly correlated with the SalePrice, hence, if one of this features tends to increase so does the sale price of the house.

# %%
## Problem 7-d

def corrFilter(x: pd.DataFrame, bound: float):
  xCorr = x.corr()
  xFiltered = xCorr[((xCorr >= bound) | (xCorr <= -bound)) & (xCorr != 1.000)]
  xFlattened  = xFiltered.unstack().sort_values().drop_duplicates()
  return xFlattened

corrFilter(df, .822)
# Out:
# GrLivArea   TotRmsAbvGrd    0.825489
# YearBuilt   GarageYrBlt     0.825667
# GarageCars  GarageArea      0.882475
# Id          Id                   NaN
# dtype: float64

# %%
## Problem 7-e
dfCorr = df.corr()
filteredDf = dfCorr[((dfCorr >= 0.822) | (dfCorr <= -0.822)) & (dfCorr !=1.000)]
plt.figure(figsize=(30, 10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.heatmap(filteredDf, annot=True, cmap="Reds", annot_kws={"size":17})
sns.set_style('white')
plt.show()
