# %% [markdown]
# <a href="https://colab.research.google.com/github/pafernannapi18/GithubIntro/blob/main/17Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# numpy and pandas for manipulation 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib_inline
import seaborn as sns

# sklearn reprocessing for dealing with categorical variables 
from sklearn.preprocessing import LabelEncoder

# Suppress warnings 
import warnings 
warnings.filterwarnings('ignore') 
# matplolib and seaborn for plotting 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
train = pd.read_csv("/content/drive/MyDrive/application_train.csv")
test = pd.read_csv("/content/drive/MyDrive/application_test.csv")

print('Training data shape:', train.shape)
print('Testing data shape:', train.shape)
# Out:
# Training data shape: (307511, 122)
# Testing data shape: (307511, 122)

# %%
train.head()
# Out:
#    SK_ID_CURR  TARGET  ... AMT_REQ_CREDIT_BUREAU_QRT AMT_REQ_CREDIT_BUREAU_YEAR
# 0      100002       1  ...                       0.0                        1.0
# 1      100003       0  ...                       0.0                        0.0
# 2      100004       0  ...                       0.0                        0.0
# 3      100006       0  ...                       NaN                        NaN
# 4      100007       0  ...                       0.0                        0.0
#
# [5 rows x 122 columns]

# %% [markdown]
# Cheking missing data and dropping columns with over 10% of missing data

# %%
total = train.isnull().sum().sort_values(ascending=False)
percent = (train.isnull().sum()/train.isnull().count()).sort_values(ascending = False)
data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
data
# Out:
#                               Total   Percent
# COMMONAREA_MEDI              214865  0.698723
# COMMONAREA_AVG               214865  0.698723
# COMMONAREA_MODE              214865  0.698723
# NONLIVINGAPARTMENTS_MODE     213514  0.694330
# NONLIVINGAPARTMENTS_MEDI     213514  0.694330
# ...                             ...       ...
# REG_CITY_NOT_LIVE_CITY            0  0.000000
# LIVE_REGION_NOT_WORK_REGION       0  0.000000
# REG_REGION_NOT_WORK_REGION        0  0.000000
# HOUR_APPR_PROCESS_START           0  0.000000
# SK_ID_CURR                        0  0.000000
#
# [122 rows x 2 columns]

# %%
features = data[data.Percent < 0.1]
features
# Out:
#                              Total   Percent
# NAME_TYPE_SUITE               1292  0.004201
# OBS_30_CNT_SOCIAL_CIRCLE      1021  0.003320
# OBS_60_CNT_SOCIAL_CIRCLE      1021  0.003320
# DEF_60_CNT_SOCIAL_CIRCLE      1021  0.003320
# DEF_30_CNT_SOCIAL_CIRCLE      1021  0.003320
# ...                            ...       ...
# REG_CITY_NOT_LIVE_CITY           0  0.000000
# LIVE_REGION_NOT_WORK_REGION      0  0.000000
# REG_REGION_NOT_WORK_REGION       0  0.000000
# HOUR_APPR_PROCESS_START          0  0.000000
# SK_ID_CURR                       0  0.000000
#
# [65 rows x 2 columns]

# %%
features.index
# Out:
# Index(['NAME_TYPE_SUITE', 'OBS_30_CNT_SOCIAL_CIRCLE',
#        'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE',
#        'DEF_30_CNT_SOCIAL_CIRCLE', 'EXT_SOURCE_2', 'AMT_GOODS_PRICE',
#        'AMT_ANNUITY', 'CNT_FAM_MEMBERS', 'DAYS_LAST_PHONE_CHANGE',
#        'AMT_CREDIT', 'FLAG_OWN_CAR', 'FLAG_EMAIL', 'TARGET', 'FLAG_PHONE',
#        'FLAG_CONT_MOBILE', 'FLAG_WORK_PHONE', 'FLAG_EMP_PHONE', 'FLAG_MOBIL',
#        'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_REALTY',
#        'AMT_INCOME_TOTAL', 'DAYS_ID_PUBLISH', 'DAYS_REGISTRATION',
#        'DAYS_EMPLOYED', 'DAYS_BIRTH', 'REGION_POPULATION_RELATIVE',
#        'REGION_RATING_CLIENT', 'NAME_FAMILY_STATUS', 'NAME_EDUCATION_TYPE',
#        'NAME_INCOME_TYPE', 'CNT_CHILDREN', 'NAME_HOUSING_TYPE',
#        'REG_REGION_NOT_LIVE_REGION', 'REGION_RATING_CLIENT_W_CITY',
#        'WEEKDAY_APPR_PROCESS_START', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3',
#        'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6',
#        'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9',
#        'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12',
#        'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15',
#        'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18',
#        'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21',
#        'ORGANIZATION_TYPE', 'LIVE_CITY_NOT_WORK_CITY',
#        'REG_CITY_NOT_WORK_CITY', 'REG_CITY_NOT_LIVE_CITY',
#        'LIVE_REGION_NOT_WORK_REGION', 'REG_REGION_NOT_WORK_REGION',
#        'HOUR_APPR_PROCESS_START', 'SK_ID_CURR'],
#       dtype='object')

# %%
train = train[features.index]
train.head()
# Out:
#   NAME_TYPE_SUITE  ...  SK_ID_CURR
# 0   Unaccompanied  ...      100002
# 1          Family  ...      100003
# 2   Unaccompanied  ...      100004
# 3   Unaccompanied  ...      100006
# 4   Unaccompanied  ...      100007
#
# [5 rows x 65 columns]

# %%
total_test = test.isnull().sum().sort_values(ascending=False)
percent = (test.isnull().sum()/test.isnull().count()).sort_values(ascending = False)
data_test = pd.concat([total_test, percent], axis=1, keys=['Total', 'Percent'])
data_test
# Out:
#                              Total   Percent
# COMMONAREA_MEDI              33495  0.687161
# COMMONAREA_AVG               33495  0.687161
# COMMONAREA_MODE              33495  0.687161
# NONLIVINGAPARTMENTS_MODE     33347  0.684125
# NONLIVINGAPARTMENTS_MEDI     33347  0.684125
# ...                            ...       ...
# REG_CITY_NOT_WORK_CITY           0  0.000000
# REG_CITY_NOT_LIVE_CITY           0  0.000000
# LIVE_REGION_NOT_WORK_REGION      0  0.000000
# REG_REGION_NOT_WORK_REGION       0  0.000000
# SK_ID_CURR                       0  0.000000
#
# [121 rows x 2 columns]

# %%
test_features = data_test[data_test.Percent < 0.1]
test_features.shape
# Out:
# (64, 2)

# %%
test = test[test_features.index]
test.head()
# Out:
#   NAME_TYPE_SUITE  ...  SK_ID_CURR
# 0   Unaccompanied  ...      100001
# 1   Unaccompanied  ...      100005
# 2             NaN  ...      100013
# 3   Unaccompanied  ...      100028
# 4   Unaccompanied  ...      100038
#
# [5 rows x 64 columns]

# %%
# Number of samples of each Label
train.TARGET.value_counts()
# Out:
# 0    282686
# 1     24825
# Name: TARGET, dtype: int64

# %%
print("0: loan repaid on time, 1:loan unpaid")
plt.pie(train["TARGET"].value_counts(), labels=['0', '1'], autopct="%1.1f%%", shadow=True, startangle=90, colors= ['red', 'pink'], textprops={'fontsize': 15})
plt.title("Loans repaid or not")
plt.show()
# Out:
# 0: loan repaid on time, 1:loan unpaid

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 65 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   NAME_TYPE_SUITE              306219 non-null  object
#  1   OBS_30_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  2   OBS_60_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  3   DEF_60_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  4   DEF_30_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  5   EXT_SOURCE_2                 306851 non-null  float64
#  6   AMT_GOODS_PRICE              307233 non-null  float64
#  7   AMT_ANNUITY                  307499 non-null  float64
#  8   CNT_FAM_MEMBERS              307509 non-null  float64
#  9   DAYS_LAST_PHONE_CHANGE       307510 non-null  float64
#  10  AMT_CREDIT                   307511 non-null  float64
#  11  FLAG_OWN_CAR                 307511 non-null  object
#  12  FLAG_EMAIL                   307511 non-null  int64
#  13  TARGET                       307511 non-null  int64
#  14  FLAG_PHONE                   307511 non-null  int64
#  15  FLAG_CONT_MOBILE             307511 non-null  int64
#  16  FLAG_WORK_PHONE              307511 non-null  int64
#  17  FLAG_EMP_PHONE               307511 non-null  int64
#  18  FLAG_MOBIL                   307511 non-null  int64
#  19  NAME_CONTRACT_TYPE           307511 non-null  object
#  20  CODE_GENDER                  307511 non-null  object
#  21  FLAG_OWN_REALTY              307511 non-null  object
#  22  AMT_INCOME_TOTAL             307511 non-null  float64
#  23  DAYS_ID_PUBLISH              307511 non-null  int64
#  24  DAYS_REGISTRATION            307511 non-null  float64
#  25  DAYS_EMPLOYED                307511 non-null  int64
#  26  DAYS_BIRTH                   307511 non-null  int64
#  27  REGION_POPULATION_RELATIVE   307511 non-null  float64
#  28  REGION_RATING_CLIENT         307511 non-null  int64
#  29  NAME_FAMILY_STATUS           307511 non-null  object
#  30  NAME_EDUCATION_TYPE          307511 non-null  object
#  31  NAME_INCOME_TYPE             307511 non-null  object
#  32  CNT_CHILDREN                 307511 non-null  int64
#  33  NAME_HOUSING_TYPE            307511 non-null  object
#  34  REG_REGION_NOT_LIVE_REGION   307511 non-null  int64
#  35  REGION_RATING_CLIENT_W_CITY  307511 non-null  int64
#  36  WEEKDAY_APPR_PROCESS_START   307511 non-null  object
#  37  FLAG_DOCUMENT_2              307511 non-null  int64
#  38  FLAG_DOCUMENT_3              307511 non-null  int64
#  39  FLAG_DOCUMENT_4              307511 non-null  int64
#  40  FLAG_DOCUMENT_5              307511 non-null  int64
#  41  FLAG_DOCUMENT_6              307511 non-null  int64
#  42  FLAG_DOCUMENT_7              307511 non-null  int64
#  43  FLAG_DOCUMENT_8              307511 non-null  int64
#  44  FLAG_DOCUMENT_9              307511 non-null  int64
#  45  FLAG_DOCUMENT_10             307511 non-null  int64
#  46  FLAG_DOCUMENT_11             307511 non-null  int64
#  47  FLAG_DOCUMENT_12             307511 non-null  int64
#  48  FLAG_DOCUMENT_13             307511 non-null  int64
#  49  FLAG_DOCUMENT_14             307511 non-null  int64
#  50  FLAG_DOCUMENT_15             307511 non-null  int64
#  51  FLAG_DOCUMENT_16             307511 non-null  int64
#  52  FLAG_DOCUMENT_17             307511 non-null  int64
#  53  FLAG_DOCUMENT_18             307511 non-null  int64
#  54  FLAG_DOCUMENT_19             307511 non-null  int64
#  55  FLAG_DOCUMENT_20             307511 non-null  int64
#  56  FLAG_DOCUMENT_21             307511 non-null  int64
#  57  ORGANIZATION_TYPE            307511 non-null  object
#  58  LIVE_CITY_NOT_WORK_CITY      307511 non-null  int64
#  59  REG_CITY_NOT_WORK_CITY       307511 non-null  int64
#  60  REG_CITY_NOT_LIVE_CITY       307511 non-null  int64
#  61  LIVE_REGION_NOT_WORK_REGION  307511 non-null  int64
#  62  REG_REGION_NOT_WORK_REGION   307511 non-null  int64
#  63  HOUR_APPR_PROCESS_START      307511 non-null  int64
#  64  SK_ID_CURR                   307511 non-null  int64
# dtypes: float64(13), int64(41), object(11)
# memory usage: 152.5+ MB

# %%
objects = train.select_dtypes(include=[object])
objects
# Out:
#        NAME_TYPE_SUITE  ...       ORGANIZATION_TYPE
# 0        Unaccompanied  ...  Business Entity Type 3
# 1               Family  ...                  School
# 2        Unaccompanied  ...              Government
# 3        Unaccompanied  ...  Business Entity Type 3
# 4        Unaccompanied  ...                Religion
# ...                ...  ...                     ...
# 307506   Unaccompanied  ...                Services
# 307507   Unaccompanied  ...                     XNA
# 307508   Unaccompanied  ...                  School
# 307509   Unaccompanied  ...  Business Entity Type 1
# 307510   Unaccompanied  ...  Business Entity Type 3
#
# [307511 rows x 11 columns]

# %%
objects.isna().sum()
# Out:
# NAME_TYPE_SUITE               1292
# FLAG_OWN_CAR                     0
# NAME_CONTRACT_TYPE               0
# CODE_GENDER                      0
# FLAG_OWN_REALTY                  0
# NAME_FAMILY_STATUS               0
# NAME_EDUCATION_TYPE              0
# NAME_INCOME_TYPE                 0
# NAME_HOUSING_TYPE                0
# WEEKDAY_APPR_PROCESS_START       0
# ORGANIZATION_TYPE                0
# dtype: int64

# %%
train['NAME_TYPE_SUITE'].value_counts()
# Out:
# Unaccompanied      248526
# Family              40149
# Spouse, partner     11370
# Children             3267
# Other_B              1770
# Other_A               866
# Group of people       271
# Name: NAME_TYPE_SUITE, dtype: int64

# %%
train['NAME_TYPE_SUITE'].isna().sum()
# Out:
# 1292

# %%
test['NAME_TYPE_SUITE'].isna().sum()
# Out:
# 911

# %%
train['NAME_TYPE_SUITE'] = train['NAME_TYPE_SUITE'].fillna('Unaccompanied')
test['NAME_TYPE_SUITE'] = test['NAME_TYPE_SUITE'].fillna('Unaccompanied')

# %%
objects = train.select_dtypes(include= [object])
objects.isna().sum()
# Out:
# NAME_TYPE_SUITE               0
# FLAG_OWN_CAR                  0
# NAME_CONTRACT_TYPE            0
# CODE_GENDER                   0
# FLAG_OWN_REALTY               0
# NAME_FAMILY_STATUS            0
# NAME_EDUCATION_TYPE           0
# NAME_INCOME_TYPE              0
# NAME_HOUSING_TYPE             0
# WEEKDAY_APPR_PROCESS_START    0
# ORGANIZATION_TYPE             0
# dtype: int64

# %%
# Create a Label encoder object 
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
objects = train.dtypes[train.dtypes == "object"].index
objects
# Out:
# Index(['NAME_TYPE_SUITE', 'FLAG_OWN_CAR', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_REALTY', 'NAME_FAMILY_STATUS', 'NAME_EDUCATION_TYPE',
#        'NAME_INCOME_TYPE', 'NAME_HOUSING_TYPE', 'WEEKDAY_APPR_PROCESS_START',
#        'ORGANIZATION_TYPE'],
#       dtype='object')

# %%
for i in objects:
  train[i] = le.fit_transform(train[i])
  test[i] = le.fit_transform(test[i])

# %%
 train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 65 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   NAME_TYPE_SUITE              307511 non-null  int64
#  1   OBS_30_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  2   OBS_60_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  3   DEF_60_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  4   DEF_30_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  5   EXT_SOURCE_2                 306851 non-null  float64
#  6   AMT_GOODS_PRICE              307233 non-null  float64
#  7   AMT_ANNUITY                  307499 non-null  float64
#  8   CNT_FAM_MEMBERS              307509 non-null  float64
#  9   DAYS_LAST_PHONE_CHANGE       307510 non-null  float64
#  10  AMT_CREDIT                   307511 non-null  float64
#  11  FLAG_OWN_CAR                 307511 non-null  int64
#  12  FLAG_EMAIL                   307511 non-null  int64
#  13  TARGET                       307511 non-null  int64
#  14  FLAG_PHONE                   307511 non-null  int64
#  15  FLAG_CONT_MOBILE             307511 non-null  int64
#  16  FLAG_WORK_PHONE              307511 non-null  int64
#  17  FLAG_EMP_PHONE               307511 non-null  int64
#  18  FLAG_MOBIL                   307511 non-null  int64
#  19  NAME_CONTRACT_TYPE           307511 non-null  int64
#  20  CODE_GENDER                  307511 non-null  int64
#  21  FLAG_OWN_REALTY              307511 non-null  int64
#  22  AMT_INCOME_TOTAL             307511 non-null  float64
#  23  DAYS_ID_PUBLISH              307511 non-null  int64
#  24  DAYS_REGISTRATION            307511 non-null  float64
#  25  DAYS_EMPLOYED                307511 non-null  int64
#  26  DAYS_BIRTH                   307511 non-null  int64
#  27  REGION_POPULATION_RELATIVE   307511 non-null  float64
#  28  REGION_RATING_CLIENT         307511 non-null  int64
#  29  NAME_FAMILY_STATUS           307511 non-null  int64
#  30  NAME_EDUCATION_TYPE          307511 non-null  int64
#  31  NAME_INCOME_TYPE             307511 non-null  int64
#  32  CNT_CHILDREN                 307511 non-null  int64
#  33  NAME_HOUSING_TYPE            307511 non-null  int64
#  34  REG_REGION_NOT_LIVE_REGION   307511 non-null  int64
#  35  REGION_RATING_CLIENT_W_CITY  307511 non-null  int64
#  36  WEEKDAY_APPR_PROCESS_START   307511 non-null  int64
#  37  FLAG_DOCUMENT_2              307511 non-null  int64
#  38  FLAG_DOCUMENT_3              307511 non-null  int64
#  39  FLAG_DOCUMENT_4              307511 non-null  int64
#  40  FLAG_DOCUMENT_5              307511 non-null  int64
#  41  FLAG_DOCUMENT_6              307511 non-null  int64
#  42  FLAG_DOCUMENT_7              307511 non-null  int64
#  43  FLAG_DOCUMENT_8              307511 non-null  int64
#  44  FLAG_DOCUMENT_9              307511 non-null  int64
#  45  FLAG_DOCUMENT_10             307511 non-null  int64
#  46  FLAG_DOCUMENT_11             307511 non-null  int64
#  47  FLAG_DOCUMENT_12             307511 non-null  int64
#  48  FLAG_DOCUMENT_13             307511 non-null  int64
#  49  FLAG_DOCUMENT_14             307511 non-null  int64
#  50  FLAG_DOCUMENT_15             307511 non-null  int64
#  51  FLAG_DOCUMENT_16             307511 non-null  int64
#  52  FLAG_DOCUMENT_17             307511 non-null  int64
#  53  FLAG_DOCUMENT_18             307511 non-null  int64
#  54  FLAG_DOCUMENT_19             307511 non-null  int64
#  55  FLAG_DOCUMENT_20             307511 non-null  int64
#  56  FLAG_DOCUMENT_21             307511 non-null  int64
#  57  ORGANIZATION_TYPE            307511 non-null  int64
#  58  LIVE_CITY_NOT_WORK_CITY      307511 non-null  int64
#  59  REG_CITY_NOT_WORK_CITY       307511 non-null  int64
#  60  REG_CITY_NOT_LIVE_CITY       307511 non-null  int64
#  61  LIVE_REGION_NOT_WORK_REGION  307511 non-null  int64
#  62  REG_REGION_NOT_WORK_REGION   307511 non-null  int64
#  63  HOUR_APPR_PROCESS_START      307511 non-null  int64
#  64  SK_ID_CURR                   307511 non-null  int64
# dtypes: float64(13), int64(52)
# memory usage: 152.5 MB

# %%
 test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48744 entries, 0 to 48743
# Data columns (total 64 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   NAME_TYPE_SUITE              48744 non-null  int64
#  1   OBS_30_CNT_SOCIAL_CIRCLE     48715 non-null  float64
#  2   OBS_60_CNT_SOCIAL_CIRCLE     48715 non-null  float64
#  3   DEF_60_CNT_SOCIAL_CIRCLE     48715 non-null  float64
#  4   DEF_30_CNT_SOCIAL_CIRCLE     48715 non-null  float64
#  5   AMT_ANNUITY                  48720 non-null  float64
#  6   EXT_SOURCE_2                 48736 non-null  float64
#  7   FLAG_MOBIL                   48744 non-null  int64
#  8   FLAG_WORK_PHONE              48744 non-null  int64
#  9   FLAG_EMP_PHONE               48744 non-null  int64
#  10  DAYS_REGISTRATION            48744 non-null  float64
#  11  FLAG_CONT_MOBILE             48744 non-null  int64
#  12  FLAG_PHONE                   48744 non-null  int64
#  13  FLAG_EMAIL                   48744 non-null  int64
#  14  CNT_FAM_MEMBERS              48744 non-null  float64
#  15  DAYS_ID_PUBLISH              48744 non-null  int64
#  16  REGION_POPULATION_RELATIVE   48744 non-null  float64
#  17  DAYS_EMPLOYED                48744 non-null  int64
#  18  DAYS_BIRTH                   48744 non-null  int64
#  19  REGION_RATING_CLIENT_W_CITY  48744 non-null  int64
#  20  NAME_HOUSING_TYPE            48744 non-null  int64
#  21  NAME_FAMILY_STATUS           48744 non-null  int64
#  22  NAME_EDUCATION_TYPE          48744 non-null  int64
#  23  NAME_INCOME_TYPE             48744 non-null  int64
#  24  AMT_GOODS_PRICE              48744 non-null  float64
#  25  AMT_CREDIT                   48744 non-null  float64
#  26  AMT_INCOME_TOTAL             48744 non-null  float64
#  27  CNT_CHILDREN                 48744 non-null  int64
#  28  FLAG_OWN_REALTY              48744 non-null  int64
#  29  FLAG_OWN_CAR                 48744 non-null  int64
#  30  CODE_GENDER                  48744 non-null  int64
#  31  NAME_CONTRACT_TYPE           48744 non-null  int64
#  32  REGION_RATING_CLIENT         48744 non-null  int64
#  33  REG_REGION_NOT_LIVE_REGION   48744 non-null  int64
#  34  WEEKDAY_APPR_PROCESS_START   48744 non-null  int64
#  35  HOUR_APPR_PROCESS_START      48744 non-null  int64
#  36  DAYS_LAST_PHONE_CHANGE       48744 non-null  float64
#  37  FLAG_DOCUMENT_2              48744 non-null  int64
#  38  FLAG_DOCUMENT_3              48744 non-null  int64
#  39  FLAG_DOCUMENT_4              48744 non-null  int64
#  40  FLAG_DOCUMENT_5              48744 non-null  int64
#  41  FLAG_DOCUMENT_6              48744 non-null  int64
#  42  FLAG_DOCUMENT_7              48744 non-null  int64
#  43  FLAG_DOCUMENT_8              48744 non-null  int64
#  44  FLAG_DOCUMENT_9              48744 non-null  int64
#  45  FLAG_DOCUMENT_10             48744 non-null  int64
#  46  FLAG_DOCUMENT_11             48744 non-null  int64
#  47  FLAG_DOCUMENT_12             48744 non-null  int64
#  48  FLAG_DOCUMENT_13             48744 non-null  int64
#  49  FLAG_DOCUMENT_14             48744 non-null  int64
#  50  FLAG_DOCUMENT_15             48744 non-null  int64
#  51  FLAG_DOCUMENT_16             48744 non-null  int64
#  52  FLAG_DOCUMENT_17             48744 non-null  int64
#  53  FLAG_DOCUMENT_18             48744 non-null  int64
#  54  FLAG_DOCUMENT_19             48744 non-null  int64
#  55  FLAG_DOCUMENT_20             48744 non-null  int64
#  56  FLAG_DOCUMENT_21             48744 non-null  int64
#  57  ORGANIZATION_TYPE            48744 non-null  int64
#  58  LIVE_CITY_NOT_WORK_CITY      48744 non-null  int64
#  59  REG_CITY_NOT_WORK_CITY       48744 non-null  int64
#  60  REG_CITY_NOT_LIVE_CITY       48744 non-null  int64
#  61  LIVE_REGION_NOT_WORK_REGION  48744 non-null  int64
#  62  REG_REGION_NOT_WORK_REGION   48744 non-null  int64
#  63  SK_ID_CURR                   48744 non-null  int64
# dtypes: float64(13), int64(51)
# memory usage: 23.8 MB

# %% [markdown]
# # Data Cleaning

# %%
# Number of columns with missing values 
train.isnull().any(axis=0).sum()
# Out:
# 9

# %%
# Number of rows with missing values
train.isnull().any(axis=1).sum()
# Out:
# 1966

# %%
variables = train.columns 
columns = variables.drop('TARGET')
columns
# Out:
# Index(['NAME_TYPE_SUITE', 'OBS_30_CNT_SOCIAL_CIRCLE',
#        'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE',
#        'DEF_30_CNT_SOCIAL_CIRCLE', 'EXT_SOURCE_2', 'AMT_GOODS_PRICE',
#        'AMT_ANNUITY', 'CNT_FAM_MEMBERS', 'DAYS_LAST_PHONE_CHANGE',
#        'AMT_CREDIT', 'FLAG_OWN_CAR', 'FLAG_EMAIL', 'FLAG_PHONE',
#        'FLAG_CONT_MOBILE', 'FLAG_WORK_PHONE', 'FLAG_EMP_PHONE', 'FLAG_MOBIL',
#        'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_REALTY',
#        'AMT_INCOME_TOTAL', 'DAYS_ID_PUBLISH', 'DAYS_REGISTRATION',
#        'DAYS_EMPLOYED', 'DAYS_BIRTH', 'REGION_POPULATION_RELATIVE',
#        'REGION_RATING_CLIENT', 'NAME_FAMILY_STATUS', 'NAME_EDUCATION_TYPE',
#        'NAME_INCOME_TYPE', 'CNT_CHILDREN', 'NAME_HOUSING_TYPE',
#        'REG_REGION_NOT_LIVE_REGION', 'REGION_RATING_CLIENT_W_CITY',
#        'WEEKDAY_APPR_PROCESS_START', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3',
#        'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6',
#        'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9',
#        'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12',
#        'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15',
#        'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18',
#        'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21',
#        'ORGANIZATION_TYPE', 'LIVE_CITY_NOT_WORK_CITY',
#        'REG_CITY_NOT_WORK_CITY', 'REG_CITY_NOT_LIVE_CITY',
#        'LIVE_REGION_NOT_WORK_REGION', 'REG_REGION_NOT_WORK_REGION',
#        'HOUR_APPR_PROCESS_START', 'SK_ID_CURR'],
#       dtype='object')

# %%
# Replacing missing values (nan) by the mean in each column 
for c in columns:
  train[c] = train[c].fillna((train[c].mean()))
  test[c] = test[c].fillna((test[c].mean()))

# %%
# Number of columns with missing values
train.isnull().any(axis=0).sum()
# Out:
# 0

# %%
# Number of columns with missing values
train.isnull().any(axis=1).sum()
# Out:
# 0

# %%
train.head()
# Out:
#    NAME_TYPE_SUITE  ...  SK_ID_CURR
# 0                6  ...      100002
# 1                1  ...      100003
# 2                6  ...      100004
# 3                6  ...      100006
# 4                6  ...      100007
#
# [5 rows x 65 columns]

# %% [markdown]
# # Learning

# %%
X = train.drop(['TARGET'], axis = 1)
y = train['TARGET']

# %%
X.shape, y.shape
# Out:
# ((307511, 64), (307511,))

# %%
X.head()
# Out:
#    NAME_TYPE_SUITE  ...  SK_ID_CURR
# 0                6  ...      100002
# 1                1  ...      100003
# 2                6  ...      100004
# 3                6  ...      100006
# 4                6  ...      100007
#
# [5 rows x 64 columns]

# %% [markdown]
# ## Splitting and Standardizing data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25)

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Learning and estimation

# %%
from sklearn import tree
dt = tree.DecisionTreeClassifier()
dt.fit(X_train, y_train)
y_preds_dt = dt.predict(X_test)

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train, y_train)
y_preds_log = log.predict(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_preds_rf = rf.predict(X_test)

# %% [markdown]
# ## Evaluation

# %%
roc_auc_score(y_test, y_preds_dt)
# Out:
# 0.5281001135219431

# %%
roc_auc_score(y_test, y_preds_log)
# Out:
# 0.5006312784450259

# %%
roc_auc_score(y_test, y_preds_rf)
# Out:
# 0.5003227000729218

# %% [markdown]
# ## [Problem 3] Estimation on test data

# %%
print('Training data shape:', train.shape)
print('Testing data shape:', test.shape)
# Out:
# Training data shape: (307511, 65)
# Testing data shape: (48744, 64)

# %% [markdown]
# ## Predicting with Decision Tree

# %%
y_preds_dt2 = dt.predict(test)

# %%
test['TARGET'] = y_preds_dt2

# %%
test.head()
# Out:
#    NAME_TYPE_SUITE  OBS_30_CNT_SOCIAL_CIRCLE  ...  SK_ID_CURR  TARGET
# 0                6                       0.0  ...      100001       1
# 1                6                       0.0  ...      100005       1
# 2                6                       0.0  ...      100013       1
# 3                6                       0.0  ...      100028       1
# 4                6                       0.0  ...      100038       1
#
# [5 rows x 65 columns]

# %%
submission_1 = test.loc[:,('SK_ID_CURR', 'TARGET')]

# %%
submission_1
# Out:
#        SK_ID_CURR  TARGET
# 0          100001       1
# 1          100005       1
# 2          100013       1
# 3          100028       1
# 4          100038       1
# ...           ...     ...
# 48739      456221       1
# 48740      456222       1
# 48741      456223       1
# 48742      456224       1
# 48743      456250       1
#
# [48744 rows x 2 columns]

# %%
submission_1.to_csv("submission_1.csv", index=False)

# %% [markdown]
# ## [Problem 4] Feature engineering

# %% [markdown]
# # Checking feature importances

# %%
imp_features = pd.DataFrame({'Feature': dt.feature_importances_}, index=X.columns).sort_values(by = 'Feature', ascending= False)

# %%
imp_features.head(10)
# Out:
#                              Feature
# EXT_SOURCE_2                0.097100
# DAYS_REGISTRATION           0.071124
# DAYS_BIRTH                  0.068754
# SK_ID_CURR                  0.067443
# DAYS_ID_PUBLISH             0.066329
# AMT_ANNUITY                 0.059310
# DAYS_LAST_PHONE_CHANGE      0.057109
# DAYS_EMPLOYED               0.056979
# REGION_POPULATION_RELATIVE  0.046163
# AMT_INCOME_TOTAL            0.044033

# %%
important = imp_features.head(10).index
important
# Out:
# Index(['EXT_SOURCE_2', 'DAYS_REGISTRATION', 'DAYS_BIRTH', 'SK_ID_CURR',
#        'DAYS_ID_PUBLISH', 'AMT_ANNUITY', 'DAYS_LAST_PHONE_CHANGE',
#        'DAYS_EMPLOYED', 'REGION_POPULATION_RELATIVE', 'AMT_INCOME_TOTAL'],
#       dtype='object')

# %%
X1 = train[important]
X2 = train[important[0:1]]
X3 = train[important[0:4]]
X4 = train[important[0:6]]
X5 = train[important[0:8]]
X6 = train[important[2:3]]
X7 = train[important[3:4]]
X8 = train[important[4:5]]
X9 = train[important[5:6]]

# %% [markdown]
# ## Defining a function to determine the index value for each feature used

# %%
def feature(X, feature):
  X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

  scaler = StandardScaler()
  scaler.fit(X_train)
  X_train = scaler.transform(X_train)
  X_test = scaler.transform(X_test)

  dt = tree.DecisionTreeClassifier()
  dt.fit(X_train, y_train)
  y_preds = dt.predict(X_test)

  roc_auc_score(y_test, y_preds)
  print(f'ROC score for {feature} is {roc_auc_score(y_test, y_preds)}')

# %%
feature(X1, 'the top 10 features')
# Out:
# ROC score for the top 10 features is 0.5255897339285964

# %%
feature(X2, 'EXIT_SOURCE_2')
# Out:
# ROC score for EXIT_SOURCE_2 is 0.5137616261734552

# %%
feature(X3, 'the top 3 features')
# Out:
# ROC score for the top 3 features is 0.514979985579289

# %%
feature(X4, 'the top 5 features')
# Out:
# ROC score for the top 5 features is 0.5204401526784665

# %%
feature(X5, 'the top 7 features')
# Out:
# ROC score for the top 7 features is 0.5204922278706755

# %%
feature(X6, 'DAYS_REGISTRATION')
# Out:
# ROC score for DAYS_REGISTRATION is 0.49999054499542095

# %%
feature(X7, 'DAYS_ID_PUBLISH')
# Out:
# ROC score for DAYS_ID_PUBLISH is 0.4986379464878654

# %%
feature(X8, 'DAYS_BIRTH')
# Out:
# ROC score for DAYS_BIRTH is 0.5000297196707124

# %%
feature(X9, 'DAYS_EMPLOYED')
# Out:
# ROC score for DAYS_EMPLOYED is 0.5000961027469875

# %% [markdown]
# ## Making an estimate for the test data of the most accurate feature

# %%
X1_train, X1_test, y_train, y_test = train_test_split(X1, y, test_size= 0.25)

scaler = StandardScaler()
scaler.fit(X1_train)
X1_train = scaler.transform(X1_train)
XF1_test = scaler.fit_transform(X1_test)

# %%
dt = tree.DecisionTreeClassifier()
dt.fit(X1_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
test1 = test[important]

# %%
y_preds = dt.predict(test1)

# %%
test['TARGET'] = y_preds

# %%
submission_2 = test.loc[:, ('SK_ID_CURR', 'TARGET')]

# %%
submission_2.to_csv("submission_2.csv", index=False)
