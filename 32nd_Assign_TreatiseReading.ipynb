# %% [markdown]
# <a href="https://colab.research.google.com/github/pafernannapi18/GithubIntro/blob/main/32nd_Assign_TreatiseReading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## [Problem 1] What Kind of method exists in the field of object detection?
#
#
# # From the abstract of the paper ['Towards Real-Time Object Detection with Region Proposal Networks'](https://arxiv.org/pdf/1506.01497.pdf), we find the 2 methods mentioned below:
#
# [1.SPPNet](https://arxiv.org/pdf/1406.4729.pdf)
#
# [2.Fast R-CNN](https://arxiv.org/pdf/1504.08083.pdf)

# %% [markdown]
# # [Problem 2] What mechanism was used to make it faster?
#
# From the introduction of the paper ['Towards Real-Time Object Detection with Region Proposal Networks'](https://arxiv.org/pdf/1506.01497.pdf), it mentions the accurate way to accelerate proposal computation is to reiplement it for the GPU.

# %% [markdown]
# # [Problem 3] How is one stage method different from the two stage method?
#
# From the 'Experiments on PASCAL VOC', ['Towards Real-Time Object Detection with Region Proposal Networks'](https://arxiv.org/pdf/1506.01497.pdf), with evidence shown on table 10 with better output results for two stage method;
#
# OverFeat is a one stage class specific detection method that uses regressors and classifiers on sliding windows over convolutional features map while the two stage method consists of class-agnostic proposals and class specific detections.
#
# More information can be gotten from the [OverFeat Paper](https://arxiv.org/pdf/1312.6229.pdf)

# %% [markdown]
# # [Problem 4] What is RPN?
#
# A Region Proposal Network, or RPN, is a fully convolutional network that simultaneously predicts object bounds and objectness scores at each position. The RPN is trained end-to-end to generate high-quality region proposals by sliding a small network over the convolutional feature map output by the last shared convolutional layer. This small network takes as input an n x n spatial window of the input convolutional feature map.
#
# Explanation in section 3.1 Region Proposal Networks of paper:
#
# ['Towards Real-Time Object Detection with Region Proposal Networks'](https://arxiv.org/pdf/1506.01497.pdf)

# %% [markdown]
# # [Problem 5] What is RoI pooling?
#
# Region of interest pooling (also known as RoI pooling) is an operation widely used in object detection tasks using convolutional neural networks. For example, to detect multiple cars and pedestrians in a single image. In the first case the system is supposed to correctly label the dominant object in an image.
#
# Related work from ['Towards Real-Time Object Detection with Region Proposal Networks'](https://arxiv.org/pdf/1506.01497.pdf) in figure 2
# ![ROI.png](data:image/png;base64,...)

# %% [markdown]
# # [Problem 6] What is the proper size for Anchor?
#
# An anchor is centered at the sliding window in question, and is associated with a scale and aspect ratio. By default, we use 3 scale and 3 aspect ratios, yielding k = 9 anchor at each sliding position.
#
# Related work from ['Towards Real-Time Object Detection with Region Proposal Networks'](https://arxiv.org/pdf/1506.01497.pdf) in figure 3
#
# ![Anchor Size.png](data:image/png;base64,...)
#
# [Further Reference](https://d2l.ai/chapter_computer-vision/anchor.html)

# %% [markdown]
# # [Problem 7] What kind of dataset is used and what kind of index value is obtained compared to the previous research?
#
# From the abstact PASCAL VOC 2007, 2012 & MS COCO datasets are used.
